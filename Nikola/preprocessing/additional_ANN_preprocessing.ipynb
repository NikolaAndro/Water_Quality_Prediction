# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import probplot
from scipy.stats import zscore

# %%
# Importing the dataset
df = pd.read_csv("./preprocessed_dataset.csv", encoding= 'unicode_escape')
# Selecting 1900 samples, because samples having indices greater than 1900 are not correct
df = df.iloc[0:1900, :]
df.shape
# Out:
# (1780, 14)

# %%
df = df.drop(["STATION CODE","LOCATIONS","STATE","year"], axis = 1)

# %%
# checking for missing values in the dataset
plt.figure(figsize=(12,8))
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.tail(15)
# Out:
#       Temp   DO    PH  Conductivity     BOD     NI  Fec_col  Tot_col  \
# 1765  27.0  4.4  8.23         390.0   1.390  0.080     14.0    150.0
# 1766  27.0  4.2  8.52         380.0   1.260  0.160     28.0   1100.0
# 1767  23.0  4.0  7.65         729.0  36.000  2.890   1190.0   2950.0
# 1768  22.0  8.0  8.31         617.0   4.400  0.655     14.0     30.0
# 1769  27.0  5.0  7.92         160.0   1.443  0.153     17.0    149.0
# 1770  25.0  7.5  7.53          87.3   1.407  0.567     32.0    133.0
# 1771  27.0  6.6  7.27         162.3   3.555  0.292     46.0    156.0
# 1772  28.0  6.8  7.12         172.3   1.723  0.198     62.0    283.0
# 1773  27.0  6.7  7.60         277.8   1.229  0.183     12.0     33.0
# 1774  28.0  7.1  6.94          95.8   0.943  0.151     10.0     26.0
# 1775  27.0  7.4  7.00          88.5   0.977  0.186     27.0    105.0
# 1776  27.0  6.6  7.81         603.2   2.675  0.263     40.0    191.0
# 1777  28.0  6.6  7.49         571.5   2.091  0.256    151.0    273.0
# ...

# %%
df.to_csv("final_dataset_ANN.csv", index = False)
