# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import probplot
from scipy.stats import zscore

# %%
df = pd.read_csv("../waters_datasets/additional_datasets/wtrqlty_2008.csv", encoding= 'unicode_escape')
df["Station Code"]=df["Station Code"].astype(object)
df.shape
# Out:
# (1207, 31)

# %%
df.head()
# Out:
#   Station Code                 Water Quality  \
# 0         1001  WATER QUALITY OF RIVER- BEAS
# 1         1002  WATER QUALITY OF RIVER- BEAS
# 2         1003  WATER QUALITY OF RIVER- BEAS
# 3         1004  WATER QUALITY OF RIVER- BEAS
# 4         1005  WATER QUALITY OF RIVER- BEAS
#
#                                   Locations        State Name  \
# 0                        BEAS AT U/S MANALI  HIMACHAL PRADESH
# 1                          BEAS AT D/S KULU  HIMACHAL PRADESH
# 2                           BEAS AT D/S AUT  HIMACHAL PRADESH
# 3                     BEAS AT U/SPANDON DAM  HIMACHAL PRADESH
# 4  BEAS AT EXIT OF TUNNEL DEHAL POWER HOUSE  HIMACHAL PRADESH
#
#    TEMPERATURE (degree Centigrade)-Minimum  \
# 0                                      3.0
# 1                                      1.5
# 2                                      2.5
# 3                                      2.0
# 4                                      9.0
#
#    TEMPERATURE (degree Centigrade)-Maximum  \
# 0                                      8.0
# 1                                     20.0
# 2                                     14.0
# 3                                     15.0
# 4                                     16.0
#
#    TEMPERATURE (degree Centigrade)-Mean  \
# 0                                   6.2
# 1                                  11.1
# 2                                   9.2
# 3                                  10.0
# 4                                  13.3
#
#    Dissolved Oxygen(D.O.) (mg/l)-Minimum  \
# 0                                    7.4
# 1                                    7.5
# 2                                    8.4
# 3                                    8.4
# 4                                    9.3
#
#    Dissolved Oxygen(D.O.) (mg/l)-Maximum  Dissolved Oxygen(D.O.) (mg/l)-Mean  \
# 0                                    9.1                                 8.6
# 1                                   10.4                                 9.2
# 2                                   11.5                                 9.8
# 3                                   11.6                                 9.5
# 4                                   12.5                                10.5
#
#    ...  NITRATE- N (mg/l)-Mean  NITRITE-N (mg/l)-Minimum  \
# 0  ...                     NaN                       0.2
# 1  ...                     NaN                       NaN
# 2  ...                     NaN                       0.2
# 3  ...                     NaN                       0.2
# 4  ...                     NaN                       0.3
#
#    NITRITE-N (mg/l)-Maximum  NITRITE-N (mg/l)-Mean  \
# 0                       0.2                    0.2
# 1                       NaN                    NaN
# 2                       0.2                    0.2
# 3                       0.2                    0.2
# 4                       0.3                    0.3
#
#    FECAL COLIFORM (MPN/100ml)-Minimum  FECAL COLIFORM (MPN/100ml)-Maximum  \
# 0                                 2.0                                23.0
# 1                                70.0                               920.0
# 2                                17.0                               130.0
# 3                                 7.0                                23.0
# 4                                13.0                               280.0
#
#    FECAL COLIFORM (MPN/100ml)-Mean  TOTAL COLIFORM (MPN/100ml)-Minimum  \
# 0                             10.0                                26.0
# 1                            495.0                               280.0
# 2                             60.0                               170.0
# 3                             13.0                                23.0
# 4                            101.0                               240.0
#
#    TOTAL COLIFORM (MPN/100ml)-Maximum  TOTAL COLIFORM (MPN/100ml)-Mean
# 0                              2400.0                            641.0
# 1                              2400.0                           1200.0
# 2                              1600.0                            897.0
# 3                               350.0                            141.0
# 4                              1600.0                            778.0
#
# [5 rows x 31 columns]

# %%
# Converting object data type to numeric
def convert_to_numeric(df):
    num_col = df.shape[1]
    # Start from index 3
    for index in range(3, num_col):
        col_name = df.iloc[:, index].name
        df[col_name] = pd.to_numeric(df[col_name], errors="coerce")
    return df

df = convert_to_numeric(df)
df.dtypes
# Out:
# Station Code                                          object
# Water Quality                                         object
# Locations                                             object
# State Name                                           float64
# TEMPERATURE (degree Centigrade)-Minimum              float64
# TEMPERATURE (degree Centigrade)-Maximum              float64
# TEMPERATURE (degree Centigrade)-Mean                 float64
# Dissolved Oxygen(D.O.) (mg/l)-Minimum                float64
# Dissolved Oxygen(D.O.) (mg/l)-Maximum                float64
# Dissolved Oxygen(D.O.) (mg/l)-Mean                   float64
# pH-Minimum                                           float64
# pH-Maximum                                           float64
# pH-Mean                                              float64
# CONDUCTIVITY (µmhos/cm)-Minimum                      float64
# CONDUCTIVITY (µmhos/cm)-Maximum                      float64
# CONDUCTIVITY (µmhos/cm)-Mean                         float64
# Biochemical oxygen demand (B.O.D.) (mg/l)-Minimum    float64
# Biochemical oxygen demand (B.O.D.) (mg/l)-Maximum    float64
# Biochemical oxygen demand (B.O.D.) (mg/l)-Mean       float64
# NITRATE- N (mg/l)-Minimum                            float64
# NITRATE- N (mg/l)-Maximum                            float64
# NITRATE- N (mg/l)-Mean                               float64
# NITRITE-N (mg/l)-Minimum                             float64
# NITRITE-N (mg/l)-Maximum                             float64
# NITRITE-N (mg/l)-Mean                                float64
# FECAL COLIFORM (MPN/100ml)-Minimum                   float64
# FECAL COLIFORM (MPN/100ml)-Maximum                   float64
# FECAL COLIFORM (MPN/100ml)-Mean                      float64
# TOTAL COLIFORM (MPN/100ml)-Minimum                   float64
# TOTAL COLIFORM (MPN/100ml)-Maximum                   float64
# TOTAL COLIFORM (MPN/100ml)-Mean                      float64
# dtype: object

# %%
# Replacing string NAN values with actual NAN value (np.nan)
def convert_to_nan(df):
    n_col = df.shape[1]
    for index in range(n_col):
        df.iloc[:, index]  = df.iloc[:, index].replace("NAN", np.nan)
    return df

df = convert_to_nan(df)
# Checking for missing values
df.isnull().sum().sort_values()
# Out:
# Station Code                                            0
# Water Quality                                           0
# Locations                                               0
# pH-Mean                                                 1
# pH-Maximum                                              1
# pH-Minimum                                              1
# CONDUCTIVITY (µmhos/cm)-Maximum                        29
# CONDUCTIVITY (µmhos/cm)-Minimum                        29
# CONDUCTIVITY (µmhos/cm)-Mean                           29
# TEMPERATURE (degree Centigrade)-Mean                   36
# TEMPERATURE (degree Centigrade)-Maximum                36
# TEMPERATURE (degree Centigrade)-Minimum                36
# Biochemical oxygen demand (B.O.D.) (mg/l)-Minimum     109
# Biochemical oxygen demand (B.O.D.) (mg/l)-Maximum     109
# Biochemical oxygen demand (B.O.D.) (mg/l)-Mean        109
# TOTAL COLIFORM (MPN/100ml)-Mean                       131
# TOTAL COLIFORM (MPN/100ml)-Minimum                    131
# TOTAL COLIFORM (MPN/100ml)-Maximum                    131
# NITRATE- N (mg/l)-Mean                                179
# NITRATE- N (mg/l)-Maximum                             179
# NITRATE- N (mg/l)-Minimum                             179
# FECAL COLIFORM (MPN/100ml)-Minimum                    202
# FECAL COLIFORM (MPN/100ml)-Maximum                    202
# FECAL COLIFORM (MPN/100ml)-Mean                       202
# Dissolved Oxygen(D.O.) (mg/l)-Minimum                 359
# Dissolved Oxygen(D.O.) (mg/l)-Maximum                 359
# Dissolved Oxygen(D.O.) (mg/l)-Mean                    359
# NITRITE-N (mg/l)-Minimum                              791
# NITRITE-N (mg/l)-Maximum                              791
# NITRITE-N (mg/l)-Mean                                 791
# State Name                                           1207
# dtype: int64

# %%
df_num = df.select_dtypes(exclude="object")
df_num_col = df_num.columns
imputer = SimpleImputer(strategy="median")

df_num = imputer.fit_transform(df_num)
df_num = pd.DataFrame(df_num, columns=df_num_col)


df_cat = df.select_dtypes(include="object")
df_Concat= pd.concat([df_cat,df_num],axis=1)

df_null = df_Concat[(df_Concat["Station Code"].isnull()) & (df_Concat["Locations"].isnull()) & (df_Concat["State Name"].isnull())]
df_null_indices = df_null.index
df_Concat.drop(df_null_indices, axis=0, inplace=True)


df_Concat.to_csv("Mer.csv",index = False)
df_Concat.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_143962/2857222270.py in <module>
#       4
#       5 df_num = imputer.fit_transform(df_num)
# ----> 6 df_num = pd.DataFrame(df_num, columns=df_num_col)
#       7
#       8
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/construction.py in _check_values_indices_shape_match(values, index, columns)
#     391         passed = values.shape
#     392         implied = (len(index), len(columns))
# --> 393         raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#     394
#     395
#
# ValueError: Shape of passed values is (1207, 27), indices imply (1207, 28)

# %%
ndf=pd.read_csv("Mer.csv")
ndf.dtypes
# Out:
# STATION CODE    float64
# LOCATIONS        object
# STATE            object
# Temp            float64
# DO              float64
# PH              float64
# Conductivity    float64
# BOD             float64
# NI              float64
# Fec_col         float64
# Tot_col         float64
# dtype: object

# %%
ndf["STATION CODE"]=ndf["STATION CODE"].astype(object)

# Using Z-Score Normalization to detect outliers
df_num = ndf.select_dtypes(exclude="object")

df_num_norm = df_num.apply(zscore, axis=0)


def indices_of_greater_than_3(df_norm):
    indices_arr = []
    n_col = df_norm.shape[1]
    for index in range(n_col):
        col_index = df_norm.iloc[: ,index]
        greater_than_3 = df_norm[col_index > 3]
        greater_than_3_index = greater_than_3.index
        indices_arr.extend(greater_than_3_index)
    return indices_arr

indices_arr = indices_of_greater_than_3(df_num_norm)
print("Number of outliers using Z-Score method-",len(indices_arr))
# Out:
# Number of outliers using Z-Score method- 118

# %%
ndf.drop(indices_arr, axis=0, inplace=True)
ndf.shape
# Out:
# (1600, 11)

# %%
# Calculating Water Quality Index of each sample
df_num = ndf.select_dtypes(exclude="object")
# Dropping year and Temp attribute because they are not used for computing WQI
df_num.drop(["Temp"], axis=1, inplace=True)

# Weight Vector(wi)
wi = np.array([0.2213, 0.2604, 0.0022, 0.4426, 0.0492, 0.0221, 0.0022])

# Standard values of parameters(si)
si = np.array([10, 8.5, 1000, 5, 45, 100, 1000])

# Ideal values of paramters(vIdeal)
vIdeal = np.array([14.6, 7, 0, 0, 0, 0, 0])

def calc_wqi(sample):
    wqi_sample = 0
    wqi_w=0
    num_col = 7
    for index in range(num_col):
        v_index = sample[index] # Obeserved value of sample at index
        v_index_ideal = vIdeal[index] # Ideal value of obeserved value
        w_index = wi[index] # weight of corresponding parameter of obeserved value
        
        std_index = si[index] # Standard value recommended for obeserved value
        q_index = (v_index - v_index_ideal) / (std_index - v_index_ideal)
        q_index = q_index * 100 # Final qi value of obeserved value
        wqi_sample += ((q_index*w_index))
        wqi_w+=w_index
        
    return wqi_sample/wqi_w

def calc_wqi_for_df(df):
    wqi_arr = []
    for index in range(df.shape[0]):
        index_row = df.iloc[index, :]
        wqi_row = calc_wqi(index_row)
        wqi_arr.append(wqi_row)
    return wqi_arr

wqi_arr = calc_wqi_for_df(df_num)
# Converting oridnary array to numpy array
wqi_arr = np.array(wqi_arr)
wqi_arr = np.reshape(wqi_arr, (-1, 1))

# Resetting index values of the dataframes
wqi_arr_df = pd.DataFrame(wqi_arr, columns=["WQI"]).reset_index()
df = ndf.reset_index()

df_wqi = pd.concat([df, pd.DataFrame(wqi_arr, columns=["WQI"])], axis=1)
df_wqi.drop("index", axis=1, inplace=True)
df_wqi.shape

# Removing the samples with negative WQI
df_neg_indices = df_wqi[(df_wqi["WQI"] < 0)].index
df_wqi.drop(df_neg_indices, axis=0, inplace=True)
df_wqi.tail()
# Out:
# D:\anaconda\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#      STATION CODE                                    LOCATIONS          STATE  \
# 1595       1498.0                           YAMUNA AT BATESWAR  UTTAR PRADESH
# 1596       1127.0                             YAMUNA AT ETAWAH  UTTAR PRADESH
# 1597       1499.0    YAMUNA AT JUHIKA B/C WITH CHANBAL- ETAWAH  UTTAR PRADESH
# 1598       2283.0                           YAMUNA AT HAMIRPUR  UTTAR PRADESH
# 1599       1069.0  YAMUNA AT ALLAHABAD DOWNSTREAM (BALUA GHAT)  UTTAR PRADESH
#
#       Temp    DO   PH  Conductivity   BOD    NI   Fec_col    Tot_col  \
# 1595  24.4   8.8  8.0        1019.0  12.2  0.79   83727.0   694091.0
# 1596  23.2   9.6  8.0        1006.0  11.2  0.79   80018.0   824455.0
# 1597  23.3  10.5  8.0         623.0   4.2  0.79  193909.0  1349364.0
# 1598  25.3   6.6  7.8         509.0   2.0  0.79   49050.0   782500.0
# 1599  25.5   7.9  8.2         563.0   2.2  2.33    2250.0     3925.0
#
#               WQI
# 1595  2156.634717
# 1596  2090.642341
# 1597  4656.735379
# 1598  1326.432310
# 1599   123.506333

# %%
df_null = df_wqi[(df_wqi["STATION CODE"].isnull())]
df_null_indices = df_null.index
df_wqi.drop(df_null_indices, axis=0, inplace=True)

df_wqi["WQI clf"] = df_wqi["WQI"].apply(lambda x: (3 if (x <= 25)  
                                        else(2 if (26<=x<=50) 
                                        else(1 if (51<=x<=75) 
                                        else 0))))


df_wqi.tail()

df_wqi.to_csv("Final.csv")

# %%
df_wqi.shape
# Out:
# (1598, 13)
